-- %% [markdown]
-- # [DbUser_auth]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DbUser_auth]    Script Date: 13/01/2025 05:35:38 p. m. ******/
CREATE DATABASE [DbUser_auth]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'DbUser_auth', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\DbUser_auth.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'DbUser_auth_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\DbUser_auth_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [DbUser_auth] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DbUser_auth].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DbUser_auth] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [DbUser_auth] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [DbUser_auth] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [DbUser_auth] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [DbUser_auth] SET ARITHABORT OFF 
GO
ALTER DATABASE [DbUser_auth] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [DbUser_auth] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [DbUser_auth] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [DbUser_auth] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [DbUser_auth] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [DbUser_auth] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [DbUser_auth] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [DbUser_auth] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [DbUser_auth] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [DbUser_auth] SET  ENABLE_BROKER 
GO
ALTER DATABASE [DbUser_auth] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [DbUser_auth] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [DbUser_auth] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [DbUser_auth] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [DbUser_auth] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [DbUser_auth] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [DbUser_auth] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [DbUser_auth] SET RECOVERY FULL 
GO
ALTER DATABASE [DbUser_auth] SET  MULTI_USER 
GO
ALTER DATABASE [DbUser_auth] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [DbUser_auth] SET DB_CHAINING OFF 
GO
ALTER DATABASE [DbUser_auth] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [DbUser_auth] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [DbUser_auth] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [DbUser_auth] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'DbUser_auth', N'ON'
GO
ALTER DATABASE [DbUser_auth] SET QUERY_STORE = ON
GO
ALTER DATABASE [DbUser_auth] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
USE [DbUser_auth]
GO

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 13/01/2025 05:35:38 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[RoleID] [int] IDENTITY(1,1) NOT NULL,
	[RoleName] [nvarchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[RoleID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 13/01/2025 05:35:38 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[UserID] [int] IDENTITY(1,1) NOT NULL,
	[Username] [nvarchar](50) NOT NULL,
	[PasswordHash] [nvarchar](255) NOT NULL,
	[RoleID] [int] NOT NULL,
	[Email] [nvarchar](100) NOT NULL,
	[CreatedAt] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[UserID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
SET IDENTITY_INSERT [dbo].[Roles] ON 
INSERT [dbo].[Roles] ([RoleID], [RoleName]) VALUES (1, N'Admin')
INSERT [dbo].[Roles] ([RoleID], [RoleName]) VALUES (2, N'User')
SET IDENTITY_INSERT [dbo].[Roles] OFF
GO

-- %% [markdown]
-- # [DF__Usuarios__Create__534D60F1]

-- %%
ALTER TABLE [dbo].[Usuarios] ADD  DEFAULT (getdate()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [FK__Usuarios__RoleID__5441852A]

-- %%
ALTER TABLE [dbo].[Usuarios]  WITH CHECK ADD FOREIGN KEY([RoleID])
REFERENCES [dbo].[Roles] ([RoleID])
GO

-- %% [markdown]
-- # [DbUser_auth]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DbUser_auth] SET  READ_WRITE 
GO
